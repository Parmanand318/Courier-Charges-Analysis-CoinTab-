# %%
#Importing required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import os

# %%
#Reading excel files

Order_Report = pd.read_excel("C:\\Users\\DM\\Downloads\\Company X - Order Report.xlsx")
Pincode_Zones = pd.read_excel("C:\\Users\\DM\\Downloads\\Company X - Pincode Zones.xlsx")
SKU_Master = pd.read_excel("C:\\Users\\DM\\Downloads\\Company X - SKU Master.xlsx")
Invoice = pd.read_excel("C:\\Users\\DM\\Downloads\\Courier Company - Invoice.xlsx")
Rates = pd.read_excel("C:\\Users\\DM\\Downloads\\Courier Company - Rates.xlsx")

# %%
Order_Report.head()
# Out:
#    ExternOrderNo              SKU  Order Qty
# 0     2001827036  8904223818706.0        1.0
# 1     2001827036  8904223819093.0        1.0
# 2     2001827036  8904223819109.0        1.0
# 3     2001827036  8904223818430.0        1.0
# 4     2001827036  8904223819277.0        1.0

# %%
Order_Report.shape
# Out:
# (400, 3)

# %%
Pincode_Zones.head()
# Out:
#    Warehouse Pincode  Customer Pincode Zone
# 0           121003.0          507101.0    d
# 1           121003.0          486886.0    d
# 2           121003.0          532484.0    d
# 3           121003.0          143001.0    b
# 4           121003.0          515591.0    d

# %%
Pincode_Zones.drop_duplicates(subset='Customer Pincode', inplace=True)

# %%
Pincode_Zones.shape
# Out:
# (108, 3)

# %%
SKU_Master.head()
# Out:
#              SKU  Weight (g)
# 0  8904223815682         210
# 1  8904223815859         165
# 2  8904223815866         113
# 3  8904223815873          65
# 4  8904223816214         120

# %%
SKU_Master.drop_duplicates(subset='SKU', inplace=True)

# %%
SKU_Master.shape
# Out:
# (65, 2)

# %%
Invoice.head()
# Out:
#         AWB Code  Unnamed: 1  Unnamed: 2    Order ID  Charged Weight  \
# 0  1091117222124         NaN         NaN  2001806232            1.30
# 1  1091117222194         NaN         NaN  2001806273            1.00
# 2  1091117222931         NaN         NaN  2001806408            2.50
# 3  1091117223244         NaN         NaN  2001806458            1.00
# 4  1091117229345         NaN         NaN  2001807012            0.15
#
#    Warehouse Pincode  Customer Pincode Zone Type of Shipment  \
# 0           121003.0            507101    d  Forward charges
# 1           121003.0            486886    d  Forward charges
# 2           121003.0            532484    d  Forward charges
# 3           121003.0            143001    b  Forward charges
# 4           121003.0            515591    d  Forward charges
#
#    Billing Amount (Rs.)
# 0                 135.0
# 1                  90.2
# 2                 224.6
# 3                  61.3
# 4                  45.4

# %%
Invoice.drop(['Unnamed: 1','Unnamed: 2'], axis=1,inplace=True)

# %%
Invoice.head()
# Out:
#         AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0  1091117222124  2001806232            1.30           121003.0
# 1  1091117222194  2001806273            1.00           121003.0
# 2  1091117222931  2001806408            2.50           121003.0
# 3  1091117223244  2001806458            1.00           121003.0
# 4  1091117229345  2001807012            0.15           121003.0
#
#    Customer Pincode Zone Type of Shipment  Billing Amount (Rs.)
# 0            507101    d  Forward charges                 135.0
# 1            486886    d  Forward charges                  90.2
# 2            532484    d  Forward charges                 224.6
# 3            143001    b  Forward charges                  61.3
# 4            515591    d  Forward charges                  45.4

# %%
Invoice.shape
# Out:
# (124, 8)

# %%
Rates.head()
# Out:
#    fwd_a_fixed  fwd_a_additional  fwd_b_fixed  fwd_b_additional  fwd_c_fixed  \
# 0            0              29.5         23.6                33         28.3
#
#    fwd_c_additional  fwd_d_fixed  fwd_d_additional  fwd_e_fixed  \
# 0              38.9         45.4              44.8         56.6
#
#    fwd_e_additional  rto_a_fixed  rto_a_additional  rto_b_fixed  \
# 0              55.5         13.6              23.6         20.5
#
#    rto_b_additional  rto_c_fixed  rto_c_additional  rto_d_fixed  \
# 0              28.3         31.9              38.9         41.3
#
#    rto_d_additional  rto_e_fixed  rto_e_additional
# 0              44.8         50.7              55.5

# %% [markdown]
# # Output Data 1

# %%
data1=pd.DataFrame()
data1[["Order ID","AWB NO."]]=Invoice[['Order ID',"AWB Code"]].copy()

# %%
data1.shape
# Out:
# (124, 2)

# %%
data1
# Out:
#        Order ID        AWB NO.
# 0    2001806232  1091117222124
# 1    2001806273  1091117222194
# 2    2001806408  1091117222931
# 3    2001806458  1091117223244
# 4    2001807012  1091117229345
# ..          ...            ...
# 119  2001812941  1091118551656
# 120  2001809383  1091117614452
# 121  2001820978  1091120922803
# 122  2001811475  1091121844806
# 123  2001811305  1091121846136
#
# [124 rows x 2 columns]

# %%
#Merging require files
Order_SKU=Order_Report.merge(SKU_Master,on='SKU',how='left')

# %%
Order_SKU.shape
# Out:
# (400, 4)

# %%
Order_SKU
# Out:
#      ExternOrderNo              SKU  Order Qty  Weight (g)
# 0       2001827036  8904223818706.0        1.0         127
# 1       2001827036  8904223819093.0        1.0         150
# 2       2001827036  8904223819109.0        1.0         100
# 3       2001827036  8904223818430.0        1.0         165
# 4       2001827036  8904223819277.0        1.0         350
# ..             ...              ...        ...         ...
# 395     2001806229  8904223818942.0        1.0         133
# 396     2001806229  8904223818850.0        1.0         240
# 397     2001806226  8904223818850.0        2.0         240
# 398     2001806210  8904223816214.0        1.0         120
# 399     2001806210  8904223818874.0        1.0         100
#
# [400 rows x 4 columns]

# %%
Order_SKU['Per Wt']=Order_SKU['Order Qty']*Order_SKU['Weight (g)'].copy()

# %%
Order_SKU.shape
# Out:
# (400, 5)

# %%
Order_SKU
# Out:
#      ExternOrderNo              SKU  Order Qty  Weight (g)  Per Wt
# 0       2001827036  8904223818706.0        1.0         127   127.0
# 1       2001827036  8904223819093.0        1.0         150   150.0
# 2       2001827036  8904223819109.0        1.0         100   100.0
# 3       2001827036  8904223818430.0        1.0         165   165.0
# 4       2001827036  8904223819277.0        1.0         350   350.0
# ..             ...              ...        ...         ...     ...
# 395     2001806229  8904223818942.0        1.0         133   133.0
# 396     2001806229  8904223818850.0        1.0         240   240.0
# 397     2001806226  8904223818850.0        2.0         240   480.0
# 398     2001806210  8904223816214.0        1.0         120   120.0
# 399     2001806210  8904223818874.0        1.0         100   100.0
#
# [400 rows x 5 columns]

# %%
Order_SKU.groupby('ExternOrderNo')['Per Wt'].sum().to_frame()
# Out:
#                Per Wt
# ExternOrderNo
# 2001806210      220.0
# 2001806226      480.0
# 2001806229      500.0
# 2001806232     1302.0
# 2001806233      245.0
# ...               ...
# 2001821995      477.0
# 2001822466     1376.0
# 2001823564      672.0
# 2001825261     1557.0
# 2001827036     1676.0
#
# [124 rows x 1 columns]

# %%
Order_SKU[Order_SKU['ExternOrderNo']==2001821995]
# Out:
#     ExternOrderNo              SKU  Order Qty  Weight (g)  Per Wt
# 18     2001821995  8904223819130.0        1.0         350   350.0
# 19     2001821995  8904223818706.0        1.0         127   127.0

# %%
data1=data1.merge(Order_SKU.groupby('ExternOrderNo')['Per Wt'].sum().to_frame(),left_on='Order ID',right_on='ExternOrderNo')

# %%
data1.shape
# Out:
# (124, 3)

# %%
data1
# Out:
#        Order ID        AWB NO.  Per Wt
# 0    2001806232  1091117222124  1302.0
# 1    2001806273  1091117222194   615.0
# 2    2001806408  1091117222931  2265.0
# 3    2001806458  1091117223244   700.0
# 4    2001807012  1091117229345   240.0
# ..          ...            ...     ...
# 119  2001812941  1091118551656   500.0
# 120  2001809383  1091117614452   607.0
# 121  2001820978  1091120922803   515.0
# 122  2001811475  1091121844806   689.0
# 123  2001811305  1091121846136   750.0
#
# [124 rows x 3 columns]

# %%
data1['Total weight as per X (KG)']=data1['Per Wt']/1000

# %%
data1.shape
# Out:
# (124, 4)

# %%
data1.drop('Per Wt',axis=1,inplace=True)

# %%
data1
# Out:
#        Order ID        AWB NO.  Total weight as per X (KG)
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
# [124 rows x 3 columns]

# %%
data1['Weight slab as per X (KG)']=np.ceil(data1['Total weight as per X (KG)']*2)/2 #np.ceil((1.3*2)/2)=1

# %%
data1.shape
# Out:
# (124, 4)

# %%
data1
# Out:
#        Order ID        AWB NO.  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)
# 0                          1.5
# 1                          1.0
# 2                          2.5
# 3                          1.0
# 4                          0.5
# ..                         ...
# ...

# %%
Invoice.rename({'AWB Code':'AWB NO.'},axis=1,inplace=True)

# %%
data1=data1.merge(Invoice[['Charged Weight','AWB NO.']],on='AWB NO.')

# %%
data1.shape
# Out:
# (124, 5)

# %%
data1
# Out:
#        Order ID        AWB NO.  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)  Charged Weight
# 0                          1.5            1.30
# 1                          1.0            1.00
# 2                          2.5            2.50
# 3                          1.0            1.00
# ...

# %%
data1.rename({'Charged Weight':'Total weight as per Courier Company (KG)'},axis=1,inplace=True)

# %%
data1['Weight slab charged by Courier Company (KG)']=np.ceil(data1['Total weight as per Courier Company (KG)']*2)/2

# %%
data1
# Out:
#        Order ID        AWB NO.  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          1.5                                      1.30
# 1                          1.0                                      1.00
# ...

# %%
Temp=Invoice.merge(Pincode_Zones,on=['Customer Pincode','Warehouse Pincode'],how='right')

# %%
Temp
# Out:
#            AWB NO.    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30           121003.0
# 1    1091117222194  2001806273            1.00           121003.0
# 2    1091117222931  2001806408            2.50           121003.0
# 3    1091117223244  2001806458            1.00           121003.0
# 4    1091117229345  2001807012            0.15           121003.0
# ..             ...         ...             ...                ...
# 119  1091117904860  2001811039            0.68           121003.0
# 120  1091121846136  2001811305            0.50           121003.0
# 121  1091118551656  2001812941            0.73           121003.0
# 122  1091117614452  2001809383            0.50           121003.0
# 123  1091120922803  2001820978            0.50           121003.0
#
#      Customer Pincode Zone_x         Type of Shipment  Billing Amount (Rs.)  \
# 0              507101      d          Forward charges                 135.0
# ...

# %%
data1=data1.merge(Temp[['Zone_y','AWB NO.']],on='AWB NO.')

# %%
data1.rename({'Zone_y':'Delivery Zone as per X'},axis=1,inplace=True)

# %%
data1.shape
# Out:
# (124, 7)

# %%
data1=data1.merge(Temp[['Zone_x','AWB NO.']],on='AWB NO.')

# %%
data1.rename({'Zone_x':'Delivery Zone charged by Courier Company'},axis=1,inplace=True)

# %%
data1.shape
# Out:
# (124, 8)

# %%
data1
# Out:
#        Order ID        AWB NO.  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          1.5                                      1.30
# 1                          1.0                                      1.00
# ...

# %%
Invoice['Type of Shipment'].value_counts()
# Out:
# Forward charges            109
# Forward and RTO charges     15
# Name: Type of Shipment, dtype: int64

# %%
Invoice[['Billing Amount (Rs.)','Zone','Charged Weight']][Invoice['Type of Shipment']=='Forward and RTO charges']
# Out:
#      Billing Amount (Rs.) Zone  Charged Weight
# 18                  107.3    e            0.20
# 22                  172.8    d            0.70
# 23                  102.3    b            0.60
# 24                  172.8    d            0.99
# 25                  172.8    d            0.70
# 26                  213.5    e            0.80
# 27                  258.9    d            1.20
# 28                  151.1    b            1.30
# 29                  172.8    d            0.70
# 30                  345.0    d            1.60
# 31                  258.9    d            1.13
# 32                  172.8    d            0.60
# 69                   86.7    d            0.50
# 73                   86.7    d            0.15
# 120                  86.7    d            0.50

# %%
for i in Rates.columns:
    var_name = i.lower().replace(" ", "_")
    exec(f"{var_name} = {Rates[i][0]}")
    print(i)
# Out:
# fwd_a_fixed
# fwd_a_additional
# fwd_b_fixed
# fwd_b_additional
# fwd_c_fixed
# fwd_c_additional
# fwd_d_fixed
# fwd_d_additional
# fwd_e_fixed
# fwd_e_additional
# rto_a_fixed
# rto_a_additional
# rto_b_fixed
# rto_b_additional
# rto_c_fixed
# rto_c_additional
# rto_d_fixed
# rto_d_additional
# rto_e_fixed
# rto_e_additional

# %%
np.ceil(0.8/0.5)
# Out:
# 2.0

# %%
Temp=Temp.merge(data1[['Weight slab as per X (KG)','AWB NO.']],on='AWB NO.')

# %%
Temp
# Out:
#            AWB NO.    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30           121003.0
# 1    1091117222194  2001806273            1.00           121003.0
# 2    1091117222931  2001806408            2.50           121003.0
# 3    1091117223244  2001806458            1.00           121003.0
# 4    1091117229345  2001807012            0.15           121003.0
# ..             ...         ...             ...                ...
# 119  1091117904860  2001811039            0.68           121003.0
# 120  1091121846136  2001811305            0.50           121003.0
# 121  1091118551656  2001812941            0.73           121003.0
# 122  1091117614452  2001809383            0.50           121003.0
# 123  1091120922803  2001820978            0.50           121003.0
#
#      Customer Pincode Zone_x         Type of Shipment  Billing Amount (Rs.)  \
# 0              507101      d          Forward charges                 135.0
# ...

# %%
Temp.dtypes
# Out:
# AWB NO.                        int64
# Order ID                       int64
# Charged Weight               float64
# Warehouse Pincode            float64
# Customer Pincode               int64
# Zone_x                        object
# Type of Shipment              object
# Billing Amount (Rs.)         float64
# Zone_y                        object
# Weight slab as per X (KG)    float64
# dtype: object

# %%
def Calc(x):
    x=x.tolist()  # Convert x to a list
    if x[2]=='Forward charges':
        if x[0]=='a':
            return fwd_a_fixed+((np.ceil(x[1]/0.5)-1)*fwd_a_additional)  # Calculate forward charges for type a
        elif x[0]=='b':
            return fwd_b_fixed+((np.ceil(x[1]/0.5)-1)*fwd_b_additional)  # Calculate forward charges for type b
        elif x[0]=='c':
            return fwd_c_fixed+((np.ceil(x[1]/0.5)-1)*fwd_c_additional)  # Calculate forward charges for type c
        elif x[0]=='d':
            return fwd_d_fixed+((np.ceil(x[1]/0.5)-1)*fwd_d_additional)  # Calculate forward charges for type d
        else:
            return fwd_e_fixed+((np.ceil(x[1]/0.5)-1)*fwd_e_additional)  # Calculate forward charges for type e
    else:
        if x[0]=='a':
            return fwd_a_fixed+((np.ceil(x[1]/0.5)-1)*fwd_a_additional)+rto_a_fixed+((np.ceil(x[1]/0.5)-1)*rto_a_additional)  # Calculate forward and RTO charges for type a
        elif x[0]=='b':
            return fwd_b_fixed+((np.ceil(x[1]/0.5)-1)*fwd_a_additional)+rto_b_fixed+((np.ceil(x[1]/0.5)-1)*rto_a_additional)  # Calculate forward and RTO charges for type b
        elif x[0]=='c':
            return fwd_c_fixed+((np.ceil(x[1]/0.5)-1)*fwd_a_additional)+rto_c_fixed+((np.ceil(x[1]/0.5)-1)*rto_a_additional)  # Calculate forward and RTO charges for type c
        elif x[0]=='d':
            return fwd_d_fixed+((np.ceil(x[1]/0.5)-1)*fwd_a_additional)+rto_d_fixed+((np.ceil(x[1]/0.5)-1)*rto_a_additional)  # Calculate forward and RTO charges for type d
        else:
            return fwd_e_fixed+((np.ceil(x[1]/0.5)-1)*fwd_a_additional)+rto_e_fixed+((np.ceil(x[1]/0.5)-1)*rto_a_additional)  # Calculate forward and RTO charges for type e

# %%
Temp['Expected Charge as per X (Rs.)']=Temp[['Zone_y','Weight slab as per X (KG)','Type of Shipment']].apply(Calc,axis=1)

# %%
Temp
# Out:
#            AWB NO.    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30           121003.0
# 1    1091117222194  2001806273            1.00           121003.0
# 2    1091117222931  2001806408            2.50           121003.0
# 3    1091117223244  2001806458            1.00           121003.0
# 4    1091117229345  2001807012            0.15           121003.0
# ..             ...         ...             ...                ...
# 119  1091117904860  2001811039            0.68           121003.0
# 120  1091121846136  2001811305            0.50           121003.0
# 121  1091118551656  2001812941            0.73           121003.0
# 122  1091117614452  2001809383            0.50           121003.0
# 123  1091120922803  2001820978            0.50           121003.0
#
#      Customer Pincode Zone_x         Type of Shipment  Billing Amount (Rs.)  \
# 0              507101      d          Forward charges                 135.0
# ...

# %%
data1=data1.merge(Temp[['Expected Charge as per X (Rs.)','AWB NO.']],on='AWB NO.')

# %%
data1
# Out:
#        Order ID        AWB NO.  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          1.5                                      1.30
# 1                          1.0                                      1.00
# ...

# %%
Temp=Temp.merge(data1[['Weight slab charged by Courier Company (KG)','AWB NO.']],on='AWB NO.')

# %%
Temp.shape
# Out:
# (124, 12)

# %%
Invoice
# Out:
#            AWB NO.    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30           121003.0
# 1    1091117222194  2001806273            1.00           121003.0
# 2    1091117222931  2001806408            2.50           121003.0
# 3    1091117223244  2001806458            1.00           121003.0
# 4    1091117229345  2001807012            0.15           121003.0
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73           121003.0
# 120  1091117614452  2001809383            0.50           121003.0
# 121  1091120922803  2001820978            0.50           121003.0
# 122  1091121844806  2001811475            0.50           121003.0
# 123  1091121846136  2001811305            0.50           121003.0
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# ...

# %%
data1=data1.merge(Invoice[['Billing Amount (Rs.)','AWB NO.']],on='AWB NO.')

# %%
Temp
# Out:
#            AWB NO.    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30           121003.0
# 1    1091117222194  2001806273            1.00           121003.0
# 2    1091117222931  2001806408            2.50           121003.0
# 3    1091117223244  2001806458            1.00           121003.0
# 4    1091117229345  2001807012            0.15           121003.0
# ..             ...         ...             ...                ...
# 119  1091117904860  2001811039            0.68           121003.0
# 120  1091121846136  2001811305            0.50           121003.0
# 121  1091118551656  2001812941            0.73           121003.0
# 122  1091117614452  2001809383            0.50           121003.0
# 123  1091120922803  2001820978            0.50           121003.0
#
#      Customer Pincode Zone_x         Type of Shipment  Billing Amount (Rs.)  \
# 0              507101      d          Forward charges                 135.0
# ...

# %%
data1.rename({'Billing Amount (Rs.)':'Charges Billed by Courier Company (Rs.)'},inplace=True,axis=1)

# %%
data1
# Out:
#        Order ID        AWB NO.  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          1.5                                      1.30
# 1                          1.0                                      1.00
# ...

# %%
data1.shape
# Out:
# (124, 10)

# %%
data1['Difference Between Expected Charges and Billed Charges (Rs.)']=data1['Expected Charge as per X (Rs.)']-data1['Charges Billed by Courier Company (Rs.)']

# %%
data1.shape
# Out:
# (124, 11)

# %%
data1
# Out:
#        Order ID        AWB NO.  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)  Total weight as per Courier Company (KG)  \
# 0                          1.5                                      1.30
# 1                          1.0                                      1.00
# ...

# %%
data1.to_excel('Data1.xlsx', encoding='Latin-1')

# %%
Conclusion=pd.DataFrame({' ' : ["Total orders where X has been correctly charged", "Total Orders where X has been overcharged", "Total Orders where X has been undercharged"],'Count':'','Amount (Rs.)':''})

# %%
Conclusion.index=Conclusion[' ']

# %%
del Conclusion[" "]

# %%
Conclusion
# Out:
#                                                 Count Amount (Rs.)
#
# Total orders where X has been correctly charged
# Total Orders where X has been overcharged
# Total Orders where X has been undercharged

# %%
Conclusion.loc[:]['Count'][0]=data1["Difference Between Expected Charges and Billed Charges (Rs.)"][data1["Difference Between Expected Charges and Billed Charges (Rs.)"]==0].value_counts()[0]

# %%
Conclusion
# Out:
#                                                 Count Amount (Rs.)
#
# Total orders where X has been correctly charged    11
# Total Orders where X has been overcharged
# Total Orders where X has been undercharged

# %%
Conclusion.loc[:]['Amount (Rs.)'][0]=data1["Charges Billed by Courier Company (Rs.)"][data1["Difference Between Expected Charges and Billed Charges (Rs.)"]==0].sum()

# %%
Conclusion
# Out:
#                                                 Count Amount (Rs.)
#
# Total orders where X has been correctly charged    11        990.4
# Total Orders where X has been overcharged
# Total Orders where X has been undercharged

# %%
Conclusion.loc[:]['Count'][1]=data1["Difference Between Expected Charges and Billed Charges (Rs.)"][data1["Difference Between Expected Charges and Billed Charges (Rs.)"]<0].value_counts().sum()

# %%
Conclusion
# Out:
#                                                 Count Amount (Rs.)
#
# Total orders where X has been correctly charged    11        990.4
# Total Orders where X has been overcharged         100
# Total Orders where X has been undercharged

# %%
Conclusion.loc[:]['Amount (Rs.)'][1]=abs(data1["Difference Between Expected Charges and Billed Charges (Rs.)"][data1["Difference Between Expected Charges and Billed Charges (Rs.)"]<0].sum())

# %%
Conclusion
# Out:
#                                                 Count Amount (Rs.)
#
# Total orders where X has been correctly charged    11        990.4
# Total Orders where X has been overcharged         100       5342.2
# Total Orders where X has been undercharged

# %%
Conclusion.loc[:]['Amount (Rs.)'][1]=abs(data1["Difference Between Expected Charges and Billed Charges (Rs.)"][data1["Difference Between Expected Charges and Billed Charges (Rs.)"]<0].sum())

# %%
Conclusion
# Out:
#                                                 Count Amount (Rs.)
#
# Total orders where X has been correctly charged    11        990.4
# Total Orders where X has been overcharged         100       5342.2
# Total Orders where X has been undercharged

# %%
Conclusion.loc[:]['Count'][2]=data1["Difference Between Expected Charges and Billed Charges (Rs.)"][data1["Difference Between Expected Charges and Billed Charges (Rs.)"]>0].value_counts().sum()

# %%
Conclusion
# Out:
#                                                 Count Amount (Rs.)
#
# Total orders where X has been correctly charged    11        990.4
# Total Orders where X has been overcharged         100       5342.2
# Total Orders where X has been undercharged         13

# %%
Conclusion.loc[:]['Amount (Rs.)'][2]=abs(data1["Difference Between Expected Charges and Billed Charges (Rs.)"][data1["Difference Between Expected Charges and Billed Charges (Rs.)"]>0].sum())

# %%
#Overall conclusion of the data which show charges imposed by courier company correct charged , overcharged or undercharged

Conclusion
# Out:
#                                                 Count Amount (Rs.)
#
# Total orders where X has been correctly charged    11        990.4
# Total Orders where X has been overcharged         100       5342.2
# Total Orders where X has been undercharged         13        487.3

# %%
Conclusion.to_excel('Conclusion.xlsx', encoding='Latin-1' )
